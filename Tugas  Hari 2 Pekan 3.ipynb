# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
#code here
plt.figure(figsize=(10,8))
data_x=np.linspace(-10,10,100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2
plt.plot(data_x,cos,label='Cos x',color='red',linestyle='solid')
plt.plot(data_x,cos3,label='3 Cos x',color='green',linestyle='dashed')
plt.plot(data_x,sin,label='Sin x',color='blue',linestyle='dashdot')
plt.plot(data_x,sin2,label='2 Sin x',color='yellow',marker='x',linestyle='none')
plt.title('Grafik Cos Sin')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.legend(loc='center')
plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
